# %%
# importing the required libraries

import pandas as pd

# %%
# reading the dataset 

df = pd.read_csv("data.csv")

# %%
# viewing the first few rows using head

df.head()

# %%
# selecting a single column by name

df['Bare_Nuclei']

# %%
# Selecting muliple columns using column names

df[['Clump_Thickness','Marginal_Adhesion']]

# %%
# selecting rows by their positions

df.iloc[:3]
# Out:
#         ID  Clump_Thickness  Cell_Size_Uniformity  Cell_Shape_Uniformity  \
# 0  1000025                5                     1                      1
# 1  1002945                5                     4                      4
# 2  1015425                3                     1                      1
# 3  1016277                6                     8                      8
# 4  1017023                4                     1                      1
# 5  1017122                8                    10                     10
# 6  1018099                1                     1                      1
#
#    Marginal_Adhesion  Single_Epithelial_Cell_Size Bare_Nuclei  \
# 0                  1                          2.0           1
# 1                  5                          NaN          10
# 2                  1                          2.0           2
# 3                  1                          3.0           4
# 4                  3                          2.0           1
# ...

# %%
# selecting columns by their positions  iloc [ range is for the rows,  range is for the columns]

df.iloc[:,:3]   


[:,:3]
# Out:
#           ID  Clump_Thickness  Cell_Size_Uniformity
# 0    1000025                5                     1
# 1    1002945                5                     4
# 2    1015425                3                     1
# 3    1016277                6                     8
# 4    1017023                4                     1
# ..       ...              ...                   ...
# 694   776715                3                     1
# 695   841769                2                     1
# 696   888820                5                    10
# 697   897471                4                     8
# 698   897471                4                     8
#
# [699 rows x 3 columns]

# %%
Subsetting the data based on some columns

dataframe[dataframe["column_name"] == 2]


df[df['Cancer_Type']==2].shape
